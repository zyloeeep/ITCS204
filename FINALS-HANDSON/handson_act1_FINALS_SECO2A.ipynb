# %%
names=["Cielo", "Raven", "Zylo", "Tatin", "Zyan", "Lich", "Pia", "Gabriel", "Khalil", "Ely", "Zoro", "Natsu", "Asta", "Dazai", "Luffy" ]

print(names)
# Out:
# ['Cielo', 'Raven', 'Zylo', 'Tatin', 'Zyan', 'Lich', 'Pia', 'Gabriel', 'Khalil', 'Ely', 'Zoro', 'Natsu', 'Asta', 'Dazai', 'Luffy']

# %%
colors=["Red", "Blue", "Green", "Yellow", "Purple", "Orange", "Black", "White", "Pink", "Gray", "Cyan", "Magenta", "Brown", "Violet", "Indigo" ]

print(colors)
# Out:
# ['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Black', 'White', 'Pink', 'Gray', 'Cyan', 'Magenta', 'Brown', 'Violet', 'Indigo']

# %%
names.append("Carmela")

print(names)
# Out:
# ['Cielo', 'Raven', 'Zylo', 'Tatin', 'Zyan', 'Lich', 'Pia', 'Gabriel', 'Khalil', 'Ely', 'Zoro', 'Natsu', 'Asta', 'Dazai', 'Luffy', 'Carmela']

# %%
colors.append("Gold")

print(colors)
# Out:
# ['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Black', 'White', 'Pink', 'Gray', 'Cyan', 'Magenta', 'Brown', 'Violet', 'Indigo', 'Gold']

# %%
names.remove("Cielo")

print(names)
# Out:
# ['Raven', 'Zylo', 'Tatin', 'Zyan', 'Lich', 'Pia', 'Gabriel', 'Khalil', 'Ely', 'Zoro', 'Natsu', 'Asta', 'Dazai', 'Luffy', 'Carmela']

# %%
colors.remove("Red")

print(colors)
# Out:
# ['Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Black', 'White', 'Pink', 'Gray', 'Cyan', 'Magenta', 'Brown', 'Violet', 'Indigo', 'Gold']

# %%
names.pop(3)
# Out:
# 'Zyan'

# %%
colors.pop(1)
# Out:
# 'Green'

# %%
print(names[2])
# Out:
# Tatin

# %%
print(colors[7])
# Out:
# Gray
