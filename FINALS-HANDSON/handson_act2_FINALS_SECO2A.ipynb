# %%
fruits={"a1":"apple", "b2":"banana", "c3":"orange", "d4":"mango", "e5":"pineapple",\
        "f6":"grapes", "g7":"watermelon", "h8":"papaya", "i9":"strawberry", "j10":"blueberry",\
        "k11":"cherry", "l12":"peach", "m13":"pear", "n14":"kiwi", "o15":"lemon",\
        "p16":"lime", "q17":"coconut", "r18":"avocado", "s19":"guava", "t20":"lychee"}

fruits
# Out:
# {'a1': 'apple',
#  'b2': 'banana',
#  'c3': 'orange',
#  'd4': 'mango',
#  'e5': 'pineapple',
#  'f6': 'grapes',
#  'g7': 'watermelon',
#  'h8': 'papaya',
#  'i9': 'strawberry',
#  'j10': 'blueberry',
#  'k11': 'cherry',
#  'l12': 'peach',
#  'm13': 'pear',
#  'n14': 'kiwi',
#  'o15': 'lemon',
#  'p16': 'lime',
#  'q17': 'coconut',
#  'r18': 'avocado',
#  's19': 'guava',
#  't20': 'lychee'}

# %%
fruits["d4"]="manga"

# %%
print(fruits["d4"])
# Out:
# manga

# %%
apps={"c1":"facebook", "c2":"instagram", "c3":"twitter", "c4":"tiktok", "c5":"google classroom",\
      "c6":"whatsapp", "c7":"messenger", "c8":"youtube", "c9":"netflix", "c10":"spotify",\
      "c11":"gmail", "c12":"google maps", "c13":"coc", "c14":"canva", "c15":"zoom",\
      "c16":"capcut", "c17":"shopee", "c18":"lazada", "c19":"discord", "c20":"reddit"}
apps
# Out:
# {'c1': 'facebook',
#  'c2': 'instagram',
#  'c3': 'twitter',
#  'c4': 'tiktok',
#  'c5': 'google classroom',
#  'c6': 'whatsapp',
#  'c7': 'messenger',
#  'c8': 'youtube',
#  'c9': 'netflix',
#  'c10': 'spotify',
#  'c11': 'gmail',
#  'c12': 'google maps',
#  'c13': 'coc',
#  'c14': 'canva',
#  'c15': 'zoom',
#  'c16': 'capcut',
#  'c17': 'shopee',
#  'c18': 'lazada',
#  'c19': 'discord',
#  'c20': 'reddit'}

# %%
apps["c13"]="clash of clans"

# %%
print(apps["c13"])
# Out:
# clash of clans
